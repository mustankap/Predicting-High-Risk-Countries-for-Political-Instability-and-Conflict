# %% [markdown]
# ## This is just a testing jupyter notebook
# You all can use this if you want to test some of the features of jupyter.
#
# # some headings are bigger ! you can ignore this
# 1. hello
# 2. no

# %%
import pandas as pd

# %%
print("hello")
# Out:
# hello

# %%
'mustansir'
# Out:
# 'mustansir'

# %%
# !pip3 list
# Out:
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Package                  Version
# ------------------------ --------------------
# aioredis                 1.3.1
# anyio                    2.0.2
# apturl                   0.5.2
# argon2-cffi              20.1.0
# asgiref                  3.3.1
# async-generator          1.10
# async-timeout            3.0.1
# asyncio                  3.4.3
# attrs                    20.3.0
# autobahn                 21.3.1
# Automat                  0.8.0
# Babel                    2.9.0
# backcall                 0.2.0
# bcrypt                   3.1.7
# beautifulsoup4           4.9.3
# bleach                   3.3.0
# blinker                  1.4
# Brlapi                   0.7.0
# cachetools               4.0.0
# certifi                  2019.11.28
# cffi                     1.14.4
# channels                 3.0.3
# channels-redis           3.2.0
# chardet                  3.0.4
# Click                    7.0
# colorama                 0.4.3
# command-not-found        0.3
# constantly               15.1.0
# cryptography             3.4.6
# cupshelpers              1.0
# cycler                   0.10.0
# daphne                   3.0.1
# dbus-python              1.2.16
# decorator                4.4.2
# defer                    1.0.6
# defusedxml               0.6.0
# deluge                   2.0.3
# distro                   1.4.0
# distro-info              0.23ubuntu1
# Django                   3.1.7
# django-crispy-forms      1.11.1
# dnspython                2.1.0
# duplicity                0.8.12.0
# email-validator          1.1.2
# entrypoints              0.3
# fasteners                0.14.1
# Flask                    1.1.2
# Flask-SQLAlchemy         2.4.4
# Flask-WTF                0.14.3
# future                   0.18.2
# GeoIP                    1.3.2
# google-api-python-client 1.7.11
# google-auth              1.5.1
# google-auth-httplib2     0.0.3
# hiredis                  1.1.0
# httplib2                 0.14.0
# hyperlink                21.0.0
# idna                     2.8
# incremental              16.10.1
# investpy                 1.0.2
# ipykernel                5.4.3
# ipython                  7.20.0
# ipython-genutils         0.2.0
# itsdangerous             1.1.0
# jedi                     0.18.0
# Jinja2                   2.11.2
# joblib                   1.0.1
# json5                    0.9.5
# jsonschema               3.2.0
# jupyter-client           6.1.11
# jupyter-core             4.7.1
# jupyter-server           1.3.0
# jupyterlab               3.0.7
# jupyterlab-pygments      0.1.2
# jupyterlab-server        2.2.0
# keyring                  18.0.1
# kiwisolver               1.3.1
# language-selector        0.1
# launchpadlib             1.10.13
# lazr.restfulclient       0.14.2
# lazr.uri                 1.0.3
# lockfile                 0.12.2
# louis                    3.12.0
# lxml                     4.6.2
# macaroonbakery           1.3.1
# Mako                     1.1.0
# MarkupSafe               1.1.0
# matplotlib               3.4.1
# mistune                  0.8.4
# monotonic                1.5
# msgpack                  1.0.2
# nbclassic                0.2.6
# nbclient                 0.5.1
# nbconvert                6.0.7
# nbformat                 5.1.2
# nest-asyncio             1.5.1
# netifaces                0.10.4
# newsapi-python           0.2.6
# nltk                     3.6.2
# notebook                 6.2.0
# numpy                    1.19.5
# oauth2client             4.1.2
# oauthlib                 3.1.0
# olefile                  0.46
# packaging                20.9
# pandas                   1.2.1
# pandocfilters            1.4.3
# paramiko                 2.6.0
# parso                    0.8.1
# pexpect                  4.6.0
# pickleshare              0.7.5
# Pillow                   7.0.0
# pip                      20.0.2
# prometheus-client        0.9.0
# prompt-toolkit           3.0.14
# protobuf                 3.6.1
# ptyprocess               0.7.0
# pyasn1                   0.4.2
# pyasn1-modules           0.2.1
# pycairo                  1.16.2
# pycparser                2.20
# pycups                   1.9.73
# PyDrive                  1.3.1
# pygame                   1.9.6
# Pygments                 2.7.4
# PyGObject                3.36.0
# PyHamcrest               1.9.0
# PyJWT                    1.7.1
# pymacaroons              0.13.0
# PyNaCl                   1.3.0
# pyOpenSSL                19.0.0
# pyparsing                2.4.7
# pyRFC3339                1.1
# pyrsistent               0.17.3
# python-apt               2.0.0+ubuntu0.20.4.3
# python-dateutil          2.7.3
# python-debian            0.1.36ubuntu1
# python-libtorrent        1.1.13
# pytz                     2019.3
# pyxdg                    0.26
# PyYAML                   5.3.1
# pyzmq                    22.0.2
# regex                    2021.4.4
# rencode                  1.0.6
# reportlab                3.5.34
# requests                 2.22.0
# requests-unixsocket      0.2.0
# rsa                      4.0
# scikit-learn             0.24.2
# scipy                    1.6.3
# SecretStorage            2.3.1
# Send2Trash               1.5.0
# service-identity         18.1.0
# setproctitle             1.1.10
# setuptools               45.2.0
# simplejson               3.16.0
# six                      1.14.0
# sniffio                  1.2.0
# soupsieve                2.1
# SQLAlchemy               1.3.22
# sqlparse                 0.4.1
# systemd-python           234
# terminado                0.9.2
# testpath                 0.4.4
# threadpoolctl            2.1.0
# tornado                  6.1
# tqdm                     4.60.0
# traitlets                5.0.5
# Twisted                  18.9.0
# txaio                    21.2.1
# ubuntu-advantage-tools   20.3
# ubuntu-drivers-common    0.0.0
# ufw                      0.36
# unattended-upgrades      0.1
# Unidecode                1.2.0
# uritemplate              0.6
# urllib3                  1.25.8
# usb-creator              0.3.7
# wadllib                  1.3.3
# wcwidth                  0.2.5
# webencodings             0.5.1
# Werkzeug                 1.0.1
# wheel                    0.34.2
# WTForms                  2.3.3
# xkit                     0.0.0
# zope.interface           4.7.1

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %pwd
# Out:
# '/home/mustansir/Predicting-High-Risk-Countries-for-Political-Instability-and-Conflict'

# %%
# %ls
# Out:
# 'Blair Huffman, Emma Marriott, April Yu, Predicting high-risk countries for political instability and conflict.pdf'
#  Dataset/
#  README.md
#  SVL.ipynb
#  testing_jupyter.ipynb

# %%
# %ls -la
# Out:
# total 392
# drwxrwxr-x  5 mustansir mustansir   4096 May 17 16:53  ./
# drwxr-xr-x 57 mustansir mustansir   4096 May 17 13:40  ../
# -rw-rw-r--  1 mustansir mustansir 258105 May 17 13:56 'Blair Huffman, Emma Marriott, April Yu, Predicting high-risk countries for political instability and conflict.pdf'
# drwxrwxr-x  4 mustansir mustansir   4096 May 17 01:39  Dataset/
# drwxrwxr-x  8 mustansir mustansir   4096 May 17 13:57  .git/
# drwxrwxr-x  2 mustansir mustansir   4096 May 16 18:07  .ipynb_checkpoints/
# -rw-rw-r--  1 mustansir mustansir     72 May 16 16:51  README.md
# -rw-rw-r--  1 mustansir mustansir  29801 May 17 13:56  SVL.ipynb
# -rw-rw-r--  1 mustansir mustansir  78330 May 17 16:53  testing_jupyter.ipynb

# %%
# %matplotlib inline

# %%
import numpy
from matplotlib import pyplot as plt

x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()

# %%
# %%timeit
s=[n*n for n in range(1000)]
# Out:
# 41 µs ± 1.74 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
people= {
    "first" :["corey","jane","john"],
    "last" : ["schafer","doe","doe"],
    "email" : ["corey@gmail.com","jane@gmail.com","john@gmail.com"]
}

# %%
import pandas as pd

# %%
df=pd.DataFrame(people)
df
# Out:
#    first     last            email
# 0  corey  schafer  corey@gmail.com
# 1   jane      doe   jane@gmail.com
# 2   john      doe   john@gmail.com

# %%
filt = (df['last']=='doe')

# %%
df[filt]
# Out:
#   first last           email
# 1  jane  doe  jane@gmail.com
# 2  john  doe  john@gmail.com

# %%
df.iloc[[0,1],[1]]
# Out:
#       last
# 0  schafer
# 1      doe

# %%
df.loc[[0,1],['email','last']]
# Out:
#              email     last
# 0  corey@gmail.com  schafer
# 1   jane@gmail.com      doe

# %%
df.shape
# Out:
# (3, 3)

# %%
mf=pd.read_csv('Dataset/training/fsi-2006.csv')
mf
# Out:
#                        Country  Year   Rank  Total  C1: Security Apparatus  \
# 0                        Sudan  2006    1st  112.3                     9.8
# 1    Congo Democratic Republic  2006    2nd  110.1                     9.8
# 2                Cote d'Ivoire  2006    3rd  109.2                     9.8
# 3                         Iraq  2006    4th  109.0                     9.8
# 4                     Zimbabwe  2006    5th  108.9                     9.4
# ..                         ...   ...    ...    ...                     ...
# 141               Switzerland   2006  142nd   18.7                     1.0
# 142                   Ireland   2006  143rd   18.6                     1.0
# 143                   Finland   2006  144th   18.2                     1.0
# 144                    Sweden   2006  144th   18.2                     1.0
# 145                    Norway   2006  146th   16.8                     1.0
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 0                         9.1                  9.7          7.5
# 1                         9.6                  9.1          8.1
# 2                         9.8                  9.8          9.0
# 3                         9.7                  9.8          8.2
# 4                         8.5                  8.5          9.8
# ..                        ...                  ...          ...
# 141                       1.0                  2.0          1.2
# 142                       1.0                  1.0          1.9
# 143                       1.0                  1.0          2.2
# 144                       1.0                  1.0          1.2
# 145                       1.0                  1.0          1.8
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0                        9.2                               9.1
# 1                        9.0                               8.0
# 2                        8.0                               8.5
# 3                        8.7                               9.1
# 4                        9.2                               9.0
# ..                       ...                               ...
# 141                      2.5                               2.0
# 142                      3.0                               2.0
# 143                      2.0                               2.0
# 144                      2.0                               2.0
# 145                      2.0                               1.0
#
#      P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 0                     9.5                  9.5               9.8
# 1                     9.0                  9.0               9.5
# 2                    10.0                  8.5               9.4
# 3                     8.5                  8.3               9.7
# 4                     8.9                  9.5               9.5
# ..                    ...                  ...               ...
# 141                   1.0                  1.0               1.5
# 142                   1.5                  1.3               1.5
# 143                   1.0                  1.0               1.5
# 144                   1.0                  1.0               1.5
# 145                   1.0                  1.0               1.5
#
#      S1: Demographic Pressures  S2: Refugees and IDPs  \
# 0                          9.6                    9.7
# 1                          9.5                    9.5
# 2                          8.8                    7.6
# 3                          8.9                    8.3
# 4                          9.7                    8.9
# ..                         ...                    ...
# 141                        3.0                    1.5
# 142                        2.0                    1.4
# 143                        3.0                    1.5
# 144                        3.0                    2.5
# 145                        3.0                    1.5
#
#      X1: External Intervention
# 0                          9.8
# 1                         10.0
# 2                         10.0
# 3                         10.0
# 4                          8.0
# ..                         ...
# 141                        1.0
# 142                        1.0
# 143                        1.0
# 144                        1.0
# 145                        1.0
#
# [146 rows x 16 columns]

# %%
mf['C1: Security Apparatus'].value_counts()
# Out:
# 1.0     18
# 5.5     14
# 2.0     12
# 7.5     11
# 6.0      7
# 7.0      6
# 6.8      6
# 9.0      5
# 4.5      4
# 8.3      4
# 6.5      4
# 9.8      4
# 4.0      4
# 8.1      3
# 9.4      3
# 6.7      3
# 2.5      3
# 8.0      3
# 8.5      3
# 3.0      3
# 7.6      3
# 5.0      2
# 7.3      2
# 9.1      2
# 3.5      1
# 8.2      1
# 6.4      1
# 5.3      1
# 7.2      1
# 9.2      1
# 3.4      1
# 5.7      1
# 5.6      1
# 3.2      1
# 10.0     1
# 8.9      1
# 4.8      1
# 6.1      1
# 6.2      1
# 7.8      1
# 4.7      1
# Name: C1: Security Apparatus, dtype: int64

# %%
mf.shape
# Out:
# (146, 16)

# %%
mf.loc[0:5,['Country','E3: Human Flight and Brain Drain']]
# Out:
#                      Country  E3: Human Flight and Brain Drain
# 0                      Sudan                               9.1
# 1  Congo Democratic Republic                               8.0
# 2              Cote d'Ivoire                               8.5
# 3                       Iraq                               9.1
# 4                   Zimbabwe                               9.0
# 5                       Chad                               8.0

# %%
mf.columns
# Out:
# Index(['Country', 'Year', 'Rank', 'Total', 'C1: Security Apparatus',
#        'C2: Factionalized Elites', 'C3: Group Grievance', 'E1: Economy',
#        'E2: Economic Inequality', 'E3: Human Flight and Brain Drain',
#        'P1: State Legitimacy', 'P2: Public Services', 'P3: Human Rights',
#        'S1: Demographic Pressures', 'S2: Refugees and IDPs',
#        'X1: External Intervention'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df
# Out:
#    first     last            email
# 0  corey  schafer  corey@gmail.com
# 1   jane      doe   jane@gmail.com
# 2   john      doe   john@gmail.com

# %%
df.set_index('email',inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#              email  first     last
# 0  corey@gmail.com  corey  schafer
# 1   jane@gmail.com   jane      doe
# 2   john@gmail.com   john      doe

# %%
filt = (mf['C1: Security Apparatus'] == 1.0) & (mf['Total']>30)
filt
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# Length: 146, dtype: bool

# %%
mf.loc[filt,'Country':'Total']
# Out:
#     Country  Year Rank  Total
# 4  Zimbabwe  2006  5th  108.9

# %%
countries = ["Sudan","Iraq","Chad","Ireland","Finland","Sweden"]
filtc = mf["Country"].isin(countries)
filtc
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# Name: Country, Length: 146, dtype: bool

# %%
mf
# Out:
#                        Country  Year   Rank  Total  C1: Security Apparatus  \
# 0                        Sudan  2006    1st  112.3                     9.8
# 1    Congo Democratic Republic  2006    2nd  110.1                     9.8
# 2                Cote d'Ivoire  2006    3rd  109.2                     9.8
# 3                         Iraq  2006    4th  109.0                     9.8
# 4                     Zimbabwe  2006    5th  108.9                     9.4
# ..                         ...   ...    ...    ...                     ...
# 141               Switzerland   2006  142nd   18.7                     1.0
# 142                   Ireland   2006  143rd   18.6                     1.0
# 143                   Finland   2006  144th   18.2                     1.0
# 144                    Sweden   2006  144th   18.2                     1.0
# 145                    Norway   2006  146th   16.8                     1.0
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 0                         9.1                  9.7          7.5
# 1                         9.6                  9.1          8.1
# 2                         9.8                  9.8          9.0
# 3                         9.7                  9.8          8.2
# 4                         8.5                  8.5          9.8
# ..                        ...                  ...          ...
# 141                       1.0                  2.0          1.2
# 142                       1.0                  1.0          1.9
# 143                       1.0                  1.0          2.2
# 144                       1.0                  1.0          1.2
# 145                       1.0                  1.0          1.8
#
#      E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0                        9.2                               9.1
# 1                        9.0                               8.0
# 2                        8.0                               8.5
# 3                        8.7                               9.1
# 4                        9.2                               9.0
# ..                       ...                               ...
# 141                      2.5                               2.0
# 142                      3.0                               2.0
# 143                      2.0                               2.0
# 144                      2.0                               2.0
# 145                      2.0                               1.0
#
#      P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 0                     9.5                  9.5               9.8
# 1                     9.0                  9.0               9.5
# 2                    10.0                  8.5               9.4
# 3                     8.5                  8.3               9.7
# 4                     8.9                  9.5               9.5
# ..                    ...                  ...               ...
# 141                   1.0                  1.0               1.5
# 142                   1.5                  1.3               1.5
# 143                   1.0                  1.0               1.5
# 144                   1.0                  1.0               1.5
# 145                   1.0                  1.0               1.5
#
#      S1: Demographic Pressures  S2: Refugees and IDPs  \
# 0                          9.6                    9.7
# 1                          9.5                    9.5
# 2                          8.8                    7.6
# 3                          8.9                    8.3
# 4                          9.7                    8.9
# ..                         ...                    ...
# 141                        3.0                    1.5
# 142                        2.0                    1.4
# 143                        3.0                    1.5
# 144                        3.0                    2.5
# 145                        3.0                    1.5
#
#      X1: External Intervention
# 0                          9.8
# 1                         10.0
# 2                         10.0
# 3                         10.0
# 4                          8.0
# ..                         ...
# 141                        1.0
# 142                        1.0
# 143                        1.0
# 144                        1.0
# 145                        1.0
#
# [146 rows x 16 columns]

# %%
mf.loc[filtc,"Country"]
# Out:
# 0    Sudan
# 3     Iraq
# 5     Chad
# Name: Country, dtype: object
